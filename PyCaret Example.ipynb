# %%
from x3_training import TrainModel
import pandas as pd

# %%
data = pd.read_csv('data_clean.csv')
trainmodel = TrainModel(data)
trainmodel.setup_train()
# Out:
# <style type="text/css">
# #T_86019_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_86019">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86019_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_86019_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86019_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86019_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_86019_row0_col1" class="data row0 col1" >8735</td>
#     </tr>
#     <tr>
#       <th id="T_86019_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_86019_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_86019_row1_col1" class="data row1 col1" >Rent</td>
#     </tr>
#     <tr>
#       <th id="T_86019_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
from pycaret.regression import *

# %%
setup(data, target='Rent')
# Out:
# <style type="text/css">
# #T_1a926_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1a926">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a926_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1a926_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a926_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a926_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_1a926_row0_col1" class="data row0 col1" >2811</td>
#     </tr>
#     <tr>
#       <th id="T_1a926_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1a926_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1a926_row1_col1" class="data row1 col1" >Rent</td>
#     </tr>
#     <tr>
#       <th id="T_1a926_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_61aa5 th {
#   text-align: left;
# }
# ...

# %%
regressor = create_model('lightgbm')
tunned_regressor = tune_model(regressor)
# Out:
# <style type="text/css">
# #T_ba84f_row10_col0, #T_ba84f_row10_col1, #T_ba84f_row10_col2, #T_ba84f_row10_col3, #T_ba84f_row10_col4, #T_ba84f_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_ba84f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba84f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_ba84f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_ba84f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_ba84f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_ba84f_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_ba84f_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
evaluate_model(tunned_regressor)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…
